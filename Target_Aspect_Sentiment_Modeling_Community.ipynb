# %% [markdown]
# # Aspect Based Sentiment Modeling for Training data
#
# ## Reading Community data

# %%
import pandas as pd

df1 = pd.read_csv('discussion_dna_messages.csv')

from bs4 import BeautifulSoup
import re

def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    cleantext = cleantext.replace('&nbsp;', ' ')
    return cleantext

def url_to_string(html):
    soup = BeautifulSoup(str(html), 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    output_text = " ".join(re.split(r'[\n\t]+', soup.get_text()))
    return output_text

df1['parsed_body'] = list(map(lambda x : cleanhtml(url_to_string(x)), list(df1['body'])))
df1.head()
# Out:
#   post_type  thread_id  message_id  parent_id  \
# 0  QUESTION    3823005     3823005        NaN
# 1     REPLY    3823005     3828873  3823005.0
# 2     REPLY    3823005     3824368  3823005.0
# 3  QUESTION    3811694     3811694        NaN
# 4     REPLY    3811694     3828414  3811694.0
#
#                                            view_href  \
# 0  https://community.cisco.com/t5/cisco-digital-n...
# 1  https://community.cisco.com/t5/cisco-digital-n...
# 2  https://community.cisco.com/t5/cisco-digital-n...
# 3  https://community.cisco.com/t5/cisco-digital-n...
# 4  https://community.cisco.com/t5/cisco-digital-n...
#
#                                                title  \
# 0  DNAC PnP: Converting IOS-XE Software from Inst...
# 1  Re: DNAC PnP: Converting IOS-XE Software from ...
# 2  Re: DNAC PnP: Converting IOS-XE Software from ...
# 3                                add ip address DNAC
# 4                            Re: add ip address DNAC
#
#                                                 body  accepted_solution tags  \
# 0  &lt;P&gt;Hello everybody,&lt;/P&gt;&lt;P&gt;&a...              False  NaN
# 1  &lt;P&gt;Hello everyone,&lt;/P&gt;&lt;P&gt;&am...               True  NaN
# 2  &lt;P&gt;After some tests it seems to be a spe...               True  NaN
# 3  &lt;P&gt;When setup was run for DNAC 10gbit po...              False  NaN
# 4  &lt;P&gt;Make sure no spaces when ip address i...               True  NaN
#
#              labels                 last_edit_time  \
# 0  Cisco DNA Center  2019-03-29T06:31:10.071-07:00
# 1               NaN  2019-03-29T06:31:10.071-07:00
# 2               NaN  2019-03-29T06:31:10.071-07:00
# 3  Cisco DNA Center  2019-03-28T11:35:39.339-07:00
# 4               NaN  2019-03-28T11:35:39.339-07:00
#
#                                          parsed_body
# 0  Hello everybody, we try to provision our switc...
# 1  Hello everyone, this behavoir belongs to a new...
# 2  After some tests it seems to be a special prob...
# 3  When setup was run for DNAC 10gbit port was no...
# 4  Make sure no spaces when ip address is entered...

# %%
df1.to_excel("output.xlsx", sheet_name="dna_discussion")

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

df1['pos_tagged_body'] = list(map(lambda x : ne_chunk(pos_tag(word_tokenize(x))), df1['parsed_body']))

df1.head()
# Out:
#   post_type  thread_id  message_id  parent_id  \
# 0  QUESTION    3823005     3823005        NaN
# 1     REPLY    3823005     3828873  3823005.0
# 2     REPLY    3823005     3824368  3823005.0
# 3  QUESTION    3811694     3811694        NaN
# 4     REPLY    3811694     3828414  3811694.0
#
#                                            view_href  \
# 0  https://community.cisco.com/t5/cisco-digital-n...
# 1  https://community.cisco.com/t5/cisco-digital-n...
# 2  https://community.cisco.com/t5/cisco-digital-n...
# 3  https://community.cisco.com/t5/cisco-digital-n...
# 4  https://community.cisco.com/t5/cisco-digital-n...
#
#                                                title  \
# 0  DNAC PnP: Converting IOS-XE Software from Inst...
# 1  Re: DNAC PnP: Converting IOS-XE Software from ...
# 2  Re: DNAC PnP: Converting IOS-XE Software from ...
# 3                                add ip address DNAC
# 4                            Re: add ip address DNAC
#
#                                                 body  accepted_solution tags  \
# 0  &lt;P&gt;Hello everybody,&lt;/P&gt;&lt;P&gt;&a...              False  NaN
# 1  &lt;P&gt;Hello everyone,&lt;/P&gt;&lt;P&gt;&am...               True  NaN
# 2  &lt;P&gt;After some tests it seems to be a spe...               True  NaN
# 3  &lt;P&gt;When setup was run for DNAC 10gbit po...              False  NaN
# 4  &lt;P&gt;Make sure no spaces when ip address i...               True  NaN
#
#              labels                 last_edit_time  \
# 0  Cisco DNA Center  2019-03-29T06:31:10.071-07:00
# 1               NaN  2019-03-29T06:31:10.071-07:00
# 2               NaN  2019-03-29T06:31:10.071-07:00
# 3  Cisco DNA Center  2019-03-28T11:35:39.339-07:00
# 4               NaN  2019-03-28T11:35:39.339-07:00
#
#                                          parsed_body  \
# 0  Hello everybody, we try to provision our switc...
# 1  Hello everyone, this behavoir belongs to a new...
# 2  After some tests it seems to be a special prob...
# 3  When setup was run for DNAC 10gbit port was no...
# 4  Make sure no spaces when ip address is entered...
#
#                                      pos_tagged_body
# 0  [[(Hello, NNP)], (everybody, NN), (,, ,), (we,...
# 1  [[(Hello, NNP)], (everyone, NN), (,, ,), (this...
# 2  [(After, IN), (some, DT), (tests, NNS), (it, P...
# 3  [(When, WRB), (setup, NN), (was, VBD), (run, V...
# 4  [[(Make, NNP)], (sure, JJ), (no, DT), (spaces,...

# %%
import spacy
import math
print(spacy.__version__)
nlp = spacy.load('en_core_web_sm')
def prop_n_tagger(text):
    tokens = []
    doc = nlp(text)
    for token in doc:
        if token.pos_ == 'PROPN':
            tokens.append(token.text)
    return tokens

def nn_tagger(text):
    tokens = []
    doc = nlp(text)
    for token in doc:
        if token.tag_ == 'NN':
            tokens.append(token.text)
    return tokens
df1['spacy_prop_n_body']  = list(map(prop_n_tagger, df1['parsed_body'])) 
df1['spacy_prop_n_title'] = list(map(prop_n_tagger, df1['title']))
df1['targets'] = df1['spacy_prop_n_body']

df1['spacy_nn_body']  = list(map(nn_tagger, df1['parsed_body'])) 
df1['spacy_nn_title'] = list(map(nn_tagger, df1['title']))
df1['aspects'] = df1['spacy_nn_body']
for index, row in df1.iterrows():
    
    spacy_prop_n = df1['spacy_prop_n_body'][index] + df1['spacy_prop_n_title'][index]
    spacy_nn = df1['spacy_nn_body'][index] + df1['spacy_nn_title'][index]
    label = df1['labels'][index]
    targets = []
    if isinstance(label, float):
        targets = list(set(spacy_prop_n))
    else:
        
        for each_prop_n in spacy_prop_n:

            if each_prop_n in label:
                targets.append(label)
            else:
                targets.append(each_prop_n)
            targets = list(set(targets))
    df1['targets'][index] = targets
    df1['aspects'][index] = spacy_nn
df1.head()
# Out:
# 2.0.9
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-250f29474caa> in <module>()
#       2 import math
#       3 print(spacy.__version__)
# ----> 4 nlp = spacy.load('en_core_web_sm')
#       5 def prop_n_tagger(text):
#       6     tokens = []
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      17             "to load. For example:\nnlp = spacy.load('{}')".format(depr_path),
#      18             'error')
# ---> 19     return util.load_model(name, **overrides)
#      20
#      21
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     113             return load_model_from_link(name, **overrides)
#     114         if is_package(name):  # installed as package
# --> 115             return load_model_from_package(name, **overrides)
#     116         if Path(name).exists():  # path to model data directory
#     117             return load_model_from_path(Path(name), **overrides)
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/util.py in load_model_from_package(name, **overrides)
#     136     """Load a model from an installed package."""
#     137     cls = importlib.import_module(name)
# --> 138     return cls.load(**overrides)
#     139
#     140
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/en_core_web_sm/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     175         msg = "Can't find model directory: %s"
#     176         raise ValueError(msg % path2str(data_path))
# --> 177     return load_model_from_path(data_path, meta, **overrides)
#     178
#     179
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     157             component = nlp.create_pipe(name, config=config)
#     158             nlp.add_pipe(component, name=name)
# --> 159     return nlp.from_disk(model_path)
#     160
#     161
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/language.py in from_disk(self, path, disable)
#     636         if not (path / 'vocab').exists():
#     637             exclude['vocab'] = True
# --> 638         util.from_disk(path, deserializers, exclude)
#     639         self._path = path
#     640         return self
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/util.py in from_disk(path, readers, exclude)
#     520     for key, reader in readers.items():
#     521         if key not in exclude:
# --> 522             reader(path / key)
#     523     return path
#     524
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/language.py in <lambda>(p, proc)
#     632             if not hasattr(proc, 'to_disk'):
#     633                 continue
# --> 634             deserializers[name] = lambda p, proc=proc: proc.from_disk(p, vocab=False)
#     635         exclude = {p: False for p in disable}
#     636         if not (path / 'vocab').exists():
#
# pipeline.pyx in spacy.pipeline.Tagger.from_disk()
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/util.py in from_disk(path, readers, exclude)
#     520     for key, reader in readers.items():
#     521         if key not in exclude:
# --> 522             reader(path / key)
#     523     return path
#     524
#
# pipeline.pyx in spacy.pipeline.Tagger.from_disk.load_model()
#
# pipeline.pyx in spacy.pipeline.Tagger.Model()
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/_ml.py in build_tagger_model(nr_class, **cfg)
#     445         else:
#     446             tok2vec = Tok2Vec(token_vector_width, embed_size,
# --> 447                               pretrained_vectors=pretrained_vectors)
#     448         softmax = with_flatten(Softmax(nr_class, token_vector_width))
#     449         model = (
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/spacy/_ml.py in Tok2Vec(width, embed_size, **kwargs)
#     276                           name='embed_shape')
#     277         if pretrained_vectors is not None:
# --> 278             glove = StaticVectors(pretrained_vectors, width, column=cols.index(ID))
#     279
#     280             embed = uniqued(
#
# /apps/dslab/anaconda/python3/lib/python3.6/site-packages/thinc/neural/_classes/static_vectors.py in __init__(self, lang, nO, drop_factor, column)
#      45         if self.nM == 0:
#      46             raise ValueError(
# ---> 47                 "Cannot create vectors table with dimension 0.\n"
#      48                 "If you're using pre-trained vectors, are the vectors loaded?")
#      49         self.nV = vectors.shape[0]
#
# ValueError: Cannot create vectors table with dimension 0.
# If you're using pre-trained vectors, are the vectors loaded?

# %%
df1.loc[df1['post_type'] == 'REPLY', 'title'] = ""
df1=df1[["thread_id","title","parsed_body"]]
df1=df1.groupby("thread_id").apply(lambda x :x.sum()).drop("thread_id",1)
#df1.groupby()
df1.head(5)
# Out:
#                                                        title  \
# thread_id
# 3186932    What’s different in SD-Access from campus fabric?
# 3186935                                  Questions about DNA
# 3193060            2960-Plus 24LC-L issue with lanlite image
# 3195145    Ask the Expert: Network of the future - Softwa...
# 3225592               Using APIC-EM for bandwidth management
#
#                                                  parsed_body
# thread_id
# 3186932    This link is the best content as far Cisco gav...
# 3186935    Hello Mohammad,   So is it safe to say that in...
# 3193060    Hi there, The feature set lanlite/ lanbase is ...
# 3195145    Hi Enrique What’s the difference between SDN a...
# 3225592    Hi all,   I have a customer interested in impl...

# %%
df2=pd.read_excel("export2_dna_data_from_201708_to_20190327.xlsx",sheet_name="dna_data", index_col="conversation_uid")
df2.head()
# Out:
#                                 month   post_date  board_uid  \
# conversation_uid
# 3679256           2018-08-01 12:00:00  2018-08-01       1025
# 3682246           2018-08-01 12:00:00  2018-08-06       1025
# 3683177           2018-08-01 12:00:00  2018-08-07       1025
# 3687913           2018-08-01 12:00:00  2018-08-14       1025
# 3689146           2018-08-01 12:00:00  2018-08-15       1025
#
#                                          board_title post_type  \
# conversation_uid
# 3679256           Digital Network Architecture (DNA)     forum
# 3682246           Digital Network Architecture (DNA)     forum
# 3683177           Digital Network Architecture (DNA)     forum
# 3687913           Digital Network Architecture (DNA)     forum
# 3689146           Digital Network Architecture (DNA)     forum
#
#                                           conversation_title  user_uid  \
# conversation_uid
# 3679256                         Orchestrate DNA Lab Build Up    310855
# 3682246            Cisco DNA application system requirements    665911
# 3683177                              c9300 DNA subscriptions    310636
# 3687913                    Cisco DNA Multiple Fabric Domains    312017
# 3689146           CSCvi01378 workaround not working for DNAC    325330
#
#                        user_login      user_sso_id  \
# conversation_uid
# 3679256                    umahar           umahar
# 3682246           graeme.antrobus  graeme.antrobus
# 3683177             abdulkarim041    abdulkarim041
# 3687913                 069521139        069521139
# 3689146                  ammahend         ammahend
#
#                                     category2  \
# conversation_uid
# 3679256           4461-network-infrastructure
# 3682246           4461-network-infrastructure
# 3683177           4461-network-infrastructure
# 3687913           4461-network-infrastructure
# 3689146           4461-network-infrastructure
#
#                                                            url_a  \
# conversation_uid
# 3679256           https://community.cisco.com/t5/-/-/m-p/3679256
# 3682246           https://community.cisco.com/t5/-/-/m-p/3682246
# 3683177           https://community.cisco.com/t5/-/-/m-p/3683177
# 3687913           https://community.cisco.com/t5/-/-/m-p/3687913
# 3689146           https://community.cisco.com/t5/-/-/m-p/3689146
#
#                                                tags  \
# conversation_uid
# 3679256                                          []
# 3682246           ["system requirements,Cisco DNA"]
# 3683177                               ["c9300 DNA"]
# 3687913                                          []
# 3689146                              ["CSCvi01378"]
#
#                                                              labels  replies  \
# conversation_uid
# 3679256           ["Automation,Cisco Digital Network Architectur...       10
# 3682246           ["Cisco DNA Center","Cisco Digital Network Arc...       16
# 3683177           ["Cisco DNA Center","Cisco Digital Network Arc...       64
# 3687913           ["Cisco DNA Center","Cisco Digital Network Arc...       12
# 3689146           ["Cisco DNA Center","Cisco Digital Network Arc...       32
#
#                   kudos_received  solution_accepted  pg_vws  ev_clks
# conversation_uid
# 3679256                        0                  0      68      207
# 3682246                       16                 16     253      773
# 3683177                       16                  0     477     1852
# 3687913                        0                 12     142      426
# 3689146                        0                  0      77      243

# %%
df2=df2[["kudos_received","solution_accepted", "pg_vws", "ev_clks", "labels"]]
df = pd.merge(df1, df2, left_index=True, right_index=True)
df.head()
# Out:
#                                               title  \
# 3679256                Orchestrate DNA Lab Build Up
# 3682246   Cisco DNA application system requirements
# 3683177                     c9300 DNA subscriptions
# 3687913           Cisco DNA Multiple Fabric Domains
# 3689146  CSCvi01378 workaround not working for DNAC
#
#                                                parsed_body  kudos_received  \
# 3679256  How we do this is take a backup prior to any D...               0
# 3682246  Hello You are talking about Cisco DNA Center ?...              16
# 3683177  Hi,   My question is regarding Cisco Catalyst ...              16
# 3687913  Hi  I have question about Multiple Fabric Doma...               0
# 3689146  hi there,   the description says:   During ini...               0
#
#          solution_accepted  pg_vws  ev_clks  \
# 3679256                  0      68      207
# 3682246                 16     253      773
# 3683177                  0     477     1852
# 3687913                 12     142      426
# 3689146                  0      77      243
#
#                                                     labels
# 3679256  ["Automation,Cisco Digital Network Architectur...
# 3682246  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3683177  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3687913  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3689146  ["Cisco DNA Center","Cisco Digital Network Arc...

# %%
from bert_serving.client import BertClient
bc = BertClient()

# %%
df['bert_encoded_title'] = bc.encode(list(df['title'])).tolist()
df['bert_encoded_body'] = bc.encode(list(df['parsed_body'])).tolist()
df.head()
# Out:
# /users/hdpaisndbx38/.local/lib/python3.6/site-packages/bert_serving/client/__init__.py:285: UserWarning: some of your sentences have more tokens than "max_seq_len=25" set on the server, as consequence you may get less-accurate or truncated embeddings.
# here is what you can do:
# - disable the length-check by create a new "BertClient(check_length=False)" when you do not want to display this warning
# - or, start a new server with a larger "max_seq_len"
#   '- or, start a new server with a larger "max_seq_len"' % self.length_limit)
#                                               title  \
# 3679256                Orchestrate DNA Lab Build Up
# 3682246   Cisco DNA application system requirements
# 3683177                     c9300 DNA subscriptions
# 3687913           Cisco DNA Multiple Fabric Domains
# 3689146  CSCvi01378 workaround not working for DNAC
#
#                                                parsed_body  kudos_received  \
# 3679256  How we do this is take a backup prior to any D...               0
# 3682246  Hello You are talking about Cisco DNA Center ?...              16
# 3683177  Hi,   My question is regarding Cisco Catalyst ...              16
# 3687913  Hi  I have question about Multiple Fabric Doma...               0
# 3689146  hi there,   the description says:   During ini...               0
#
#          solution_accepted  pg_vws  ev_clks  \
# 3679256                  0      68      207
# 3682246                 16     253      773
# 3683177                  0     477     1852
# 3687913                 12     142      426
# 3689146                  0      77      243
#
#                                                     labels  \
# 3679256  ["Automation,Cisco Digital Network Architectur...
# 3682246  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3683177  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3687913  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3689146  ["Cisco DNA Center","Cisco Digital Network Arc...
#
#                                         bert_encoded_title  \
# 3679256  [0.46215784549713135, -0.22273358702659607, -0...
# 3682246  [-0.0262641329318285, 0.08413064479827881, 0.3...
# 3683177  [-0.0857071578502655, -0.14488472044467926, 0....
# 3687913  [0.3810253143310547, -0.39611005783081055, -0....
# 3689146  [-0.19243969023227692, -0.41035279631614685, 0...
#
#                                          bert_encoded_body
# 3679256  [0.051789797842502594, -0.18707872927188873, 0...
# 3682246  [0.178992360830307, -0.2956380844116211, 0.270...
# 3683177  [0.07088686525821686, -0.34869205951690674, 0....
# 3687913  [0.05355852097272873, -0.5974192023277283, 0.5...
# 3689146  [-0.16016054153442383, -0.15357112884521484, 0...

# %%
import numpy as np
average_kudos_acceptances = np.mean(df['kudos_received'] + df['solution_accepted'])
std_kudos_acceptances = np.std(df['kudos_received'] + df['solution_accepted'])
df.loc[df.kudos_received + df.solution_accepted >= average_kudos_acceptances, 'output_label'] = '1'
df.loc[df.kudos_received + df.solution_accepted < average_kudos_acceptances, 'output_label'] = '0'

df.head()
# Out:
#                                               title  \
# 3679256                Orchestrate DNA Lab Build Up
# 3682246   Cisco DNA application system requirements
# 3683177                     c9300 DNA subscriptions
# 3687913           Cisco DNA Multiple Fabric Domains
# 3689146  CSCvi01378 workaround not working for DNAC
#
#                                                parsed_body  kudos_received  \
# 3679256  How we do this is take a backup prior to any D...               0
# 3682246  Hello You are talking about Cisco DNA Center ?...              16
# 3683177  Hi,   My question is regarding Cisco Catalyst ...              16
# 3687913  Hi  I have question about Multiple Fabric Doma...               0
# 3689146  hi there,   the description says:   During ini...               0
#
#          solution_accepted  pg_vws  ev_clks  \
# 3679256                  0      68      207
# 3682246                 16     253      773
# 3683177                  0     477     1852
# 3687913                 12     142      426
# 3689146                  0      77      243
#
#                                                     labels  \
# 3679256  ["Automation,Cisco Digital Network Architectur...
# 3682246  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3683177  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3687913  ["Cisco DNA Center","Cisco Digital Network Arc...
# 3689146  ["Cisco DNA Center","Cisco Digital Network Arc...
#
#                                         bert_encoded_title  \
# 3679256  [0.46215784549713135, -0.22273358702659607, -0...
# 3682246  [-0.0262641329318285, 0.08413064479827881, 0.3...
# 3683177  [-0.0857071578502655, -0.14488472044467926, 0....
# 3687913  [0.3810253143310547, -0.39611005783081055, -0....
# 3689146  [-0.19243969023227692, -0.41035279631614685, 0...
#
#                                          bert_encoded_body output_label
# 3679256  [0.051789797842502594, -0.18707872927188873, 0...            0
# 3682246  [0.178992360830307, -0.2956380844116211, 0.270...            1
# 3683177  [0.07088686525821686, -0.34869205951690674, 0....            1
# 3687913  [0.05355852097272873, -0.5974192023277283, 0.5...            1
# 3689146  [-0.16016054153442383, -0.15357112884521484, 0...            0

# %%
df["output_label"].value_counts()
# Out:
# 0    78
# 1    44
# Name: output_label, dtype: int64

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Flatten, LSTM, Conv1D, MaxPooling1D, Dropout, Activation
import tensorflow as tf

def create_model(input_size, output_size):
    model = Sequential()
    model.add(Dense(128, input_dim=768, activation='relu'))
    model.add(Dense(output_size, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(df[['bert_encoded_title', 'bert_encoded_body']], df['output_label'], test_size=0.15, random_state=20)

# %%
combined_bert_encoding = np.mean( (X_train['bert_encoded_title'], X_train['bert_encoded_body']), axis=0)

output_labels = Y_train.values

print(combined_bert_encoding.shape)
print(output_labels.shape)
from keras.callbacks import ModelCheckpoint
model = create_model(input_size=768, output_size=1)
filepath="tabsa_weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
model.fit(combined_bert_encoding, output_labels, validation_split=0.15, epochs = 100, shuffle=True, batch_size=64, callbacks=callbacks_list)
# Out:
# (103, 768)
# (103,)
# Train on 87 samples, validate on 16 samples
# Epoch 1/100
# 87/87 [==============================] - 1s 7ms/step - loss: 0.6785 - acc: 0.5862 - val_loss: 0.7354 - val_acc: 0.6250
#
# Epoch 00001: val_acc improved from -inf to 0.62500, saving model to tabsa_weights-improvement-01-0.62.hdf5
# Epoch 2/100
# 87/87 [==============================] - 0s 488us/step - loss: 0.6163 - acc: 0.6897 - val_loss: 0.6887 - val_acc: 0.6250
#
# Epoch 00002: val_acc did not improve from 0.62500
# Epoch 3/100
# 87/87 [==============================] - 0s 727us/step - loss: 0.5754 - acc: 0.6782 - val_loss: 0.6757 - val_acc: 0.6250
#
# Epoch 00003: val_acc did not improve from 0.62500
# Epoch 4/100
# 87/87 [==============================] - 0s 262us/step - loss: 0.5580 - acc: 0.7701 - val_loss: 0.6732 - val_acc: 0.6250
#
# Epoch 00004: val_acc did not improve from 0.62500
# Epoch 5/100
# 87/87 [==============================] - 0s 495us/step - loss: 0.5190 - acc: 0.7356 - val_loss: 0.6880 - val_acc: 0.6250
#
# Epoch 00005: val_acc did not improve from 0.62500
# Epoch 6/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.4891 - acc: 0.7356 - val_loss: 0.6958 - val_acc: 0.6250
#
# Epoch 00006: val_acc did not improve from 0.62500
# Epoch 7/100
# 87/87 [==============================] - 0s 677us/step - loss: 0.4668 - acc: 0.7356 - val_loss: 0.6863 - val_acc: 0.6250
#
# Epoch 00007: val_acc did not improve from 0.62500
# Epoch 8/100
# 87/87 [==============================] - 0s 929us/step - loss: 0.4418 - acc: 0.7931 - val_loss: 0.6650 - val_acc: 0.6250
#
# Epoch 00008: val_acc did not improve from 0.62500
# Epoch 9/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.4212 - acc: 0.8391 - val_loss: 0.6478 - val_acc: 0.6250
#
# Epoch 00009: val_acc did not improve from 0.62500
# Epoch 10/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.4123 - acc: 0.9195 - val_loss: 0.6473 - val_acc: 0.6250
#
# Epoch 00010: val_acc did not improve from 0.62500
# Epoch 11/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.3905 - acc: 0.8851 - val_loss: 0.6658 - val_acc: 0.6250
#
# Epoch 00011: val_acc did not improve from 0.62500
# Epoch 12/100
# 87/87 [==============================] - 0s 725us/step - loss: 0.3640 - acc: 0.8391 - val_loss: 0.6623 - val_acc: 0.5625
#
# Epoch 00012: val_acc did not improve from 0.62500
# Epoch 13/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.3453 - acc: 0.8391 - val_loss: 0.6476 - val_acc: 0.6250
#
# Epoch 00013: val_acc did not improve from 0.62500
# Epoch 14/100
# 87/87 [==============================] - 0s 686us/step - loss: 0.3280 - acc: 0.9195 - val_loss: 0.6363 - val_acc: 0.6250
#
# Epoch 00014: val_acc did not improve from 0.62500
# Epoch 15/100
# 87/87 [==============================] - 0s 558us/step - loss: 0.3174 - acc: 0.9655 - val_loss: 0.6413 - val_acc: 0.6250
#
# Epoch 00015: val_acc did not improve from 0.62500
# Epoch 16/100
# 87/87 [==============================] - 0s 599us/step - loss: 0.2990 - acc: 0.9655 - val_loss: 0.6589 - val_acc: 0.6250
#
# Epoch 00016: val_acc did not improve from 0.62500
# Epoch 17/100
# 87/87 [==============================] - 0s 754us/step - loss: 0.2796 - acc: 0.9655 - val_loss: 0.6719 - val_acc: 0.6250
#
# Epoch 00017: val_acc did not improve from 0.62500
# Epoch 18/100
# 87/87 [==============================] - 0s 811us/step - loss: 0.2659 - acc: 0.9540 - val_loss: 0.6749 - val_acc: 0.6250
#
# Epoch 00018: val_acc did not improve from 0.62500
# Epoch 19/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.2512 - acc: 0.9770 - val_loss: 0.6640 - val_acc: 0.6250
#
# Epoch 00019: val_acc did not improve from 0.62500
# Epoch 20/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.2376 - acc: 0.9885 - val_loss: 0.6668 - val_acc: 0.6250
#
# Epoch 00020: val_acc did not improve from 0.62500
# Epoch 21/100
# 87/87 [==============================] - 0s 439us/step - loss: 0.2248 - acc: 0.9885 - val_loss: 0.6826 - val_acc: 0.6250
#
# Epoch 00021: val_acc did not improve from 0.62500
# Epoch 22/100
# 87/87 [==============================] - 0s 251us/step - loss: 0.2143 - acc: 0.9885 - val_loss: 0.6744 - val_acc: 0.6250
#
# Epoch 00022: val_acc did not improve from 0.62500
# Epoch 23/100
# 87/87 [==============================] - 0s 858us/step - loss: 0.2003 - acc: 0.9885 - val_loss: 0.6661 - val_acc: 0.6250
#
# Epoch 00023: val_acc did not improve from 0.62500
# Epoch 24/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1987 - acc: 0.9885 - val_loss: 0.6758 - val_acc: 0.6250
#
# Epoch 00024: val_acc did not improve from 0.62500
# Epoch 25/100
# 87/87 [==============================] - 0s 723us/step - loss: 0.1813 - acc: 1.0000 - val_loss: 0.7138 - val_acc: 0.6250
#
# Epoch 00025: val_acc did not improve from 0.62500
# Epoch 26/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1712 - acc: 0.9885 - val_loss: 0.7435 - val_acc: 0.6250
#
# Epoch 00026: val_acc did not improve from 0.62500
# Epoch 27/100
# 87/87 [==============================] - 0s 597us/step - loss: 0.1657 - acc: 0.9885 - val_loss: 0.7386 - val_acc: 0.6250
#
# Epoch 00027: val_acc did not improve from 0.62500
# Epoch 28/100
# 87/87 [==============================] - 0s 376us/step - loss: 0.1515 - acc: 1.0000 - val_loss: 0.7262 - val_acc: 0.5625
#
# Epoch 00028: val_acc did not improve from 0.62500
# Epoch 29/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1459 - acc: 1.0000 - val_loss: 0.7300 - val_acc: 0.5625
#
# Epoch 00029: val_acc did not improve from 0.62500
# Epoch 30/100
# 87/87 [==============================] - 0s 654us/step - loss: 0.1359 - acc: 1.0000 - val_loss: 0.7696 - val_acc: 0.5625
#
# Epoch 00030: val_acc did not improve from 0.62500
# Epoch 31/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.1336 - acc: 1.0000 - val_loss: 0.7941 - val_acc: 0.6250
#
# Epoch 00031: val_acc did not improve from 0.62500
# Epoch 32/100
# 87/87 [==============================] - 0s 873us/step - loss: 0.1250 - acc: 1.0000 - val_loss: 0.7689 - val_acc: 0.5625
#
# Epoch 00032: val_acc did not improve from 0.62500
# Epoch 33/100
# 87/87 [==============================] - 0s 272us/step - loss: 0.1145 - acc: 1.0000 - val_loss: 0.7700 - val_acc: 0.5625
#
# Epoch 00033: val_acc did not improve from 0.62500
# Epoch 34/100
# 87/87 [==============================] - 0s 215us/step - loss: 0.1085 - acc: 1.0000 - val_loss: 0.7793 - val_acc: 0.5625
#
# Epoch 00034: val_acc did not improve from 0.62500
# Epoch 35/100
# 87/87 [==============================] - 0s 754us/step - loss: 0.1026 - acc: 1.0000 - val_loss: 0.7884 - val_acc: 0.5625
#
# Epoch 00035: val_acc did not improve from 0.62500
# Epoch 36/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0972 - acc: 1.0000 - val_loss: 0.8022 - val_acc: 0.5625
#
# Epoch 00036: val_acc did not improve from 0.62500
# Epoch 37/100
# 87/87 [==============================] - 0s 357us/step - loss: 0.0920 - acc: 1.0000 - val_loss: 0.8179 - val_acc: 0.5625
#
# Epoch 00037: val_acc did not improve from 0.62500
# Epoch 38/100
# 87/87 [==============================] - 0s 171us/step - loss: 0.0877 - acc: 1.0000 - val_loss: 0.8251 - val_acc: 0.6250
#
# Epoch 00038: val_acc did not improve from 0.62500
# Epoch 39/100
# 87/87 [==============================] - 0s 456us/step - loss: 0.0832 - acc: 1.0000 - val_loss: 0.8300 - val_acc: 0.6250
#
# Epoch 00039: val_acc did not improve from 0.62500
# Epoch 40/100
# 87/87 [==============================] - 0s 229us/step - loss: 0.0791 - acc: 1.0000 - val_loss: 0.8306 - val_acc: 0.6250
#
# Epoch 00040: val_acc did not improve from 0.62500
# Epoch 41/100
# 87/87 [==============================] - 0s 407us/step - loss: 0.0755 - acc: 1.0000 - val_loss: 0.8218 - val_acc: 0.5625
#
# Epoch 00041: val_acc did not improve from 0.62500
# Epoch 42/100
# 87/87 [==============================] - 0s 877us/step - loss: 0.0712 - acc: 1.0000 - val_loss: 0.8282 - val_acc: 0.5625
#
# Epoch 00042: val_acc did not improve from 0.62500
# Epoch 43/100
# 87/87 [==============================] - 0s 499us/step - loss: 0.0676 - acc: 1.0000 - val_loss: 0.8348 - val_acc: 0.6250
#
# Epoch 00043: val_acc did not improve from 0.62500
# Epoch 44/100
# 87/87 [==============================] - 0s 930us/step - loss: 0.0646 - acc: 1.0000 - val_loss: 0.8438 - val_acc: 0.6250
#
# Epoch 00044: val_acc did not improve from 0.62500
# Epoch 45/100
# 87/87 [==============================] - 0s 947us/step - loss: 0.0616 - acc: 1.0000 - val_loss: 0.8449 - val_acc: 0.6875
#
# Epoch 00045: val_acc improved from 0.62500 to 0.68750, saving model to tabsa_weights-improvement-45-0.69.hdf5
# Epoch 46/100
# 87/87 [==============================] - 0s 884us/step - loss: 0.0589 - acc: 1.0000 - val_loss: 0.8431 - val_acc: 0.6250
#
# Epoch 00046: val_acc did not improve from 0.68750
# Epoch 47/100
# 87/87 [==============================] - 0s 654us/step - loss: 0.0564 - acc: 1.0000 - val_loss: 0.8471 - val_acc: 0.6250
#
# Epoch 00047: val_acc did not improve from 0.68750
# Epoch 48/100
# 87/87 [==============================] - 0s 931us/step - loss: 0.0538 - acc: 1.0000 - val_loss: 0.8629 - val_acc: 0.6875
#
# Epoch 00048: val_acc did not improve from 0.68750
# Epoch 49/100
# 87/87 [==============================] - 0s 760us/step - loss: 0.0511 - acc: 1.0000 - val_loss: 0.8762 - val_acc: 0.6875
#
# Epoch 00049: val_acc did not improve from 0.68750
# Epoch 50/100
# 87/87 [==============================] - 0s 559us/step - loss: 0.0489 - acc: 1.0000 - val_loss: 0.8863 - val_acc: 0.6250
#
# Epoch 00050: val_acc did not improve from 0.68750
# Epoch 51/100
# 87/87 [==============================] - 0s 252us/step - loss: 0.0468 - acc: 1.0000 - val_loss: 0.8847 - val_acc: 0.6875
#
# Epoch 00051: val_acc did not improve from 0.68750
# Epoch 52/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0446 - acc: 1.0000 - val_loss: 0.8758 - val_acc: 0.6250
#
# Epoch 00052: val_acc did not improve from 0.68750
# Epoch 53/100
# 87/87 [==============================] - 0s 993us/step - loss: 0.0434 - acc: 1.0000 - val_loss: 0.8751 - val_acc: 0.6250
#
# Epoch 00053: val_acc did not improve from 0.68750
# Epoch 54/100
# 87/87 [==============================] - 0s 821us/step - loss: 0.0422 - acc: 1.0000 - val_loss: 0.8911 - val_acc: 0.6250
#
# Epoch 00054: val_acc did not improve from 0.68750
# Epoch 55/100
# 87/87 [==============================] - 0s 444us/step - loss: 0.0400 - acc: 1.0000 - val_loss: 0.9239 - val_acc: 0.6250
#
# Epoch 00055: val_acc did not improve from 0.68750
# Epoch 56/100
# 87/87 [==============================] - 0s 383us/step - loss: 0.0380 - acc: 1.0000 - val_loss: 0.9414 - val_acc: 0.6250
#
# Epoch 00056: val_acc did not improve from 0.68750
# Epoch 57/100
# 87/87 [==============================] - 0s 199us/step - loss: 0.0369 - acc: 1.0000 - val_loss: 0.9431 - val_acc: 0.6250
#
# Epoch 00057: val_acc did not improve from 0.68750
# Epoch 58/100
# 87/87 [==============================] - 0s 433us/step - loss: 0.0353 - acc: 1.0000 - val_loss: 0.9385 - val_acc: 0.6250
#
# Epoch 00058: val_acc did not improve from 0.68750
# Epoch 59/100
# 87/87 [==============================] - 0s 306us/step - loss: 0.0338 - acc: 1.0000 - val_loss: 0.9392 - val_acc: 0.6250
#
# Epoch 00059: val_acc did not improve from 0.68750
# Epoch 60/100
# 87/87 [==============================] - 0s 713us/step - loss: 0.0325 - acc: 1.0000 - val_loss: 0.9504 - val_acc: 0.6250
#
# Epoch 00060: val_acc did not improve from 0.68750
# Epoch 61/100
# 87/87 [==============================] - 0s 677us/step - loss: 0.0314 - acc: 1.0000 - val_loss: 0.9611 - val_acc: 0.6250
#
# Epoch 00061: val_acc did not improve from 0.68750
# Epoch 62/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0301 - acc: 1.0000 - val_loss: 0.9570 - val_acc: 0.6250
#
# Epoch 00062: val_acc did not improve from 0.68750
# Epoch 63/100
# 87/87 [==============================] - 0s 538us/step - loss: 0.0291 - acc: 1.0000 - val_loss: 0.9546 - val_acc: 0.6875
#
# Epoch 00063: val_acc did not improve from 0.68750
# Epoch 64/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0282 - acc: 1.0000 - val_loss: 0.9614 - val_acc: 0.6250
#
# Epoch 00064: val_acc did not improve from 0.68750
# Epoch 65/100
# 87/87 [==============================] - 0s 732us/step - loss: 0.0272 - acc: 1.0000 - val_loss: 0.9729 - val_acc: 0.6250
#
# Epoch 00065: val_acc did not improve from 0.68750
# Epoch 66/100
# 87/87 [==============================] - 0s 1000us/step - loss: 0.0263 - acc: 1.0000 - val_loss: 0.9799 - val_acc: 0.6250
#
# Epoch 00066: val_acc did not improve from 0.68750
# Epoch 67/100
# 87/87 [==============================] - 0s 942us/step - loss: 0.0254 - acc: 1.0000 - val_loss: 0.9925 - val_acc: 0.6250
#
# Epoch 00067: val_acc did not improve from 0.68750
# Epoch 68/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0246 - acc: 1.0000 - val_loss: 1.0023 - val_acc: 0.6250
#
# Epoch 00068: val_acc did not improve from 0.68750
# Epoch 69/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0239 - acc: 1.0000 - val_loss: 1.0003 - val_acc: 0.6250
#
# Epoch 00069: val_acc did not improve from 0.68750
# Epoch 70/100
# 87/87 [==============================] - 0s 401us/step - loss: 0.0230 - acc: 1.0000 - val_loss: 0.9890 - val_acc: 0.6250
#
# Epoch 00070: val_acc did not improve from 0.68750
# Epoch 71/100
# 87/87 [==============================] - 0s 140us/step - loss: 0.0224 - acc: 1.0000 - val_loss: 0.9833 - val_acc: 0.6875
#
# Epoch 00071: val_acc did not improve from 0.68750
# Epoch 72/100
# 87/87 [==============================] - 0s 323us/step - loss: 0.0219 - acc: 1.0000 - val_loss: 0.9922 - val_acc: 0.6875
#
# Epoch 00072: val_acc did not improve from 0.68750
# Epoch 73/100
# 87/87 [==============================] - 0s 819us/step - loss: 0.0212 - acc: 1.0000 - val_loss: 1.0088 - val_acc: 0.6250
#
# Epoch 00073: val_acc did not improve from 0.68750
# Epoch 74/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0204 - acc: 1.0000 - val_loss: 1.0189 - val_acc: 0.6250
#
# Epoch 00074: val_acc did not improve from 0.68750
# Epoch 75/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0199 - acc: 1.0000 - val_loss: 1.0202 - val_acc: 0.6250
#
# Epoch 00075: val_acc did not improve from 0.68750
# Epoch 76/100
# 87/87 [==============================] - 0s 400us/step - loss: 0.0192 - acc: 1.0000 - val_loss: 1.0150 - val_acc: 0.6250
#
# Epoch 00076: val_acc did not improve from 0.68750
# Epoch 77/100
# 87/87 [==============================] - 0s 294us/step - loss: 0.0187 - acc: 1.0000 - val_loss: 1.0136 - val_acc: 0.6875
#
# Epoch 00077: val_acc did not improve from 0.68750
# Epoch 78/100
# 87/87 [==============================] - 0s 993us/step - loss: 0.0182 - acc: 1.0000 - val_loss: 1.0155 - val_acc: 0.6875
#
# Epoch 00078: val_acc did not improve from 0.68750
# Epoch 79/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0177 - acc: 1.0000 - val_loss: 1.0182 - val_acc: 0.6875
#
# Epoch 00079: val_acc did not improve from 0.68750
# Epoch 80/100
# 87/87 [==============================] - 0s 413us/step - loss: 0.0173 - acc: 1.0000 - val_loss: 1.0231 - val_acc: 0.6875
#
# Epoch 00080: val_acc did not improve from 0.68750
# Epoch 81/100
# 87/87 [==============================] - 0s 2ms/step - loss: 0.0168 - acc: 1.0000 - val_loss: 1.0326 - val_acc: 0.6250
#
# Epoch 00081: val_acc did not improve from 0.68750
# Epoch 82/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0164 - acc: 1.0000 - val_loss: 1.0504 - val_acc: 0.6250
#
# Epoch 00082: val_acc did not improve from 0.68750
# Epoch 83/100
# 87/87 [==============================] - 0s 2ms/step - loss: 0.0159 - acc: 1.0000 - val_loss: 1.0523 - val_acc: 0.6250
#
# Epoch 00083: val_acc did not improve from 0.68750
# Epoch 84/100
# 87/87 [==============================] - 0s 998us/step - loss: 0.0155 - acc: 1.0000 - val_loss: 1.0436 - val_acc: 0.6250
#
# Epoch 00084: val_acc did not improve from 0.68750
# Epoch 85/100
# 87/87 [==============================] - 0s 798us/step - loss: 0.0150 - acc: 1.0000 - val_loss: 1.0377 - val_acc: 0.6875
#
# Epoch 00085: val_acc did not improve from 0.68750
# Epoch 86/100
# 87/87 [==============================] - 0s 770us/step - loss: 0.0148 - acc: 1.0000 - val_loss: 1.0367 - val_acc: 0.6875
#
# Epoch 00086: val_acc did not improve from 0.68750
# Epoch 87/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0144 - acc: 1.0000 - val_loss: 1.0460 - val_acc: 0.6875
#
# Epoch 00087: val_acc did not improve from 0.68750
# Epoch 88/100
# 87/87 [==============================] - 0s 880us/step - loss: 0.0140 - acc: 1.0000 - val_loss: 1.0523 - val_acc: 0.6875
#
# Epoch 00088: val_acc did not improve from 0.68750
# Epoch 89/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0136 - acc: 1.0000 - val_loss: 1.0550 - val_acc: 0.6875
#
# Epoch 00089: val_acc did not improve from 0.68750
# Epoch 90/100
# 87/87 [==============================] - 0s 273us/step - loss: 0.0133 - acc: 1.0000 - val_loss: 1.0580 - val_acc: 0.6875
#
# Epoch 00090: val_acc did not improve from 0.68750
# Epoch 91/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0129 - acc: 1.0000 - val_loss: 1.0618 - val_acc: 0.6875
#
# Epoch 00091: val_acc did not improve from 0.68750
# Epoch 92/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 1.0673 - val_acc: 0.6875
#
# Epoch 00092: val_acc did not improve from 0.68750
# Epoch 93/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0123 - acc: 1.0000 - val_loss: 1.0770 - val_acc: 0.6875
#
# Epoch 00093: val_acc did not improve from 0.68750
# Epoch 94/100
# 87/87 [==============================] - 0s 695us/step - loss: 0.0121 - acc: 1.0000 - val_loss: 1.0860 - val_acc: 0.6250
#
# Epoch 00094: val_acc did not improve from 0.68750
# Epoch 95/100
# 87/87 [==============================] - 0s 527us/step - loss: 0.0118 - acc: 1.0000 - val_loss: 1.0911 - val_acc: 0.6250
#
# Epoch 00095: val_acc did not improve from 0.68750
# Epoch 96/100
# 87/87 [==============================] - 0s 214us/step - loss: 0.0115 - acc: 1.0000 - val_loss: 1.0892 - val_acc: 0.6250
#
# Epoch 00096: val_acc did not improve from 0.68750
# Epoch 97/100
# 87/87 [==============================] - 0s 140us/step - loss: 0.0113 - acc: 1.0000 - val_loss: 1.0893 - val_acc: 0.6875
#
# Epoch 00097: val_acc did not improve from 0.68750
# Epoch 98/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0110 - acc: 1.0000 - val_loss: 1.0979 - val_acc: 0.6250
#
# Epoch 00098: val_acc did not improve from 0.68750
# Epoch 99/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0108 - acc: 1.0000 - val_loss: 1.1065 - val_acc: 0.6250
#
# Epoch 00099: val_acc did not improve from 0.68750
# Epoch 100/100
# 87/87 [==============================] - 0s 1ms/step - loss: 0.0106 - acc: 1.0000 - val_loss: 1.1071 - val_acc: 0.6250
#
# Epoch 00100: val_acc did not improve from 0.68750

# %%
combined_bert_encoding_test = np.mean( (X_test['bert_encoded_title'], X_test['bert_encoded_body']), axis=0)
output_labels_test = Y_test.values
results = model.evaluate(x=combined_bert_encoding_test, y=output_labels_test)
# Out:
# 19/19 [==============================] - 0s 470us/step

# %%
metrics = model.metrics_names
results_dict = dict(zip(metrics, results))
print("Results:", results_dict)
# Out:
# Results: {'loss': 1.2244435548782349, 'acc': 0.5263158082962036}
